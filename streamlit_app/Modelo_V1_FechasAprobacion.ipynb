# %% [markdown]
# # Descripción
# Primera versión del modelo de estimación de fechas de aprobacion sin mucha limpieza de datos

# %%
import numpy as np
import pandas as pd
import missingno as msn
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
#Direccion del documento
#path=os.path.dirname(os.path.realpath('Ordenes%20de%20compra%20PORTAL%201K%20(datos%20completo).xlsx'))
#path

# %%
#Subir la dirección local de donde tengan los datos
df=pd.read_excel('C:\\Users\\Admin\\OneDrive\\Documentos\\DataScience2021-2\\Trabajos_propios_felipe\\Proyecto_final\\Ordenes de compra PORTAL 1K (datos completo).xlsx')

# %%
#Manejo inicial de base de datos
df.drop(labels=['Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28'],axis=1,inplace=True)
df.drop_duplicates(inplace=True)

#Cambiando formato de variables
df['FECHA ORDEN']=pd.to_datetime(df['FECHA ORDEN'],format='%Y-%m-%d',errors = 'coerce')
df['FECHA ENTREGA']=pd.to_datetime(df['FECHA ENTREGA'],format='%Y-%m-%d',errors = 'coerce')
df['FECHA APROBACION']=pd.to_datetime(df['FECHA APROBACION'],format='%Y-%m-%d',errors = 'coerce')
df['FECHA ULTIMO MOVIMIENTO']=pd.to_datetime(df['FECHA ULTIMO MOVIMIENTO'],format='%Y-%m-%d',errors = 'coerce')
df['PRECIO UNITARIO']=df['PRECIO UNITARIO'].apply(lambda x:float(x.replace('.','')))
df['PRECIO UNITARIO + IVA']=df['PRECIO UNITARIO + IVA'].apply(lambda x:float(x.replace('.','')))
df['IVA']=df['IVA'].apply(lambda x:float(x.replace('.','')))
df['TOTAL SIN IVA']=df['TOTAL SIN IVA'].apply(lambda x:float(x.replace('.','')))
df['TOTAL + IVA']=df['TOTAL + IVA'].apply(lambda x:float(x.replace('.','')))

#Eliminamos columnas que no usaremos
df.drop(labels=['CANTIDAD RECIBIDA','CENTRO DE COSTOS','PRESUPUESTO'],inplace=True,axis=1)

# %%
#Creacion de nuevos features

#Con las fechas de aprobacion
df['dia fecha aprobacion']=df['FECHA APROBACION'].dt.dayofweek #0 lunes, 6 domingo
df['mes fecha aprobacion']=df['FECHA APROBACION'].dt.month #Meses de aprobación 
df['semana del año aprobacion']=df['FECHA APROBACION'].dt.isocalendar().week

#Con las fechas de orden
df['dia fecha orden']=df['FECHA ORDEN'].dt.dayofweek #0 lunes, 6 domingo
df['mes fecha orden']=df['FECHA ORDEN'].dt.month #Meses de ordbación 
df['semana del año orden']=df['FECHA ORDEN'].dt.isocalendar().week

#Variable objetivo
df['dias para aprobación']=df['FECHA APROBACION']-df['FECHA ORDEN']
df['dias para aprobación']=(df['FECHA APROBACION']-df['FECHA ORDEN']).dt.days

# %%
#df.dropna(inplace=True)

# %%
#Los sias de aprobación superior a 7 dias los organizo para que sean 7
df['dias para aprobación']=np.where(df['dias para aprobación']>df['dias para aprobación'].quantile(0.75),
                                    df['dias para aprobación'].quantile(0.75),df['dias para aprobación'])

# %%
df['dias para aprobación'].describe()
# Out:
# count    21259.000000
# mean         2.243662
# std          2.991787
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          7.000000
# max          7.000000
# Name: dias para aprobación, dtype: float64

# %% [markdown]
# # MODELO

# %%
from pycaret.regression import *
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Variables usadas para entrenar el modelo inicial:
# - Dia fecha aprobacion = Dia de la semana que se aprobo la orden (lunes,martes...sabado,domingo)
# - Dia fecha orden = Dia de la semana que se hizo la orden(lunes,martes...sabado,domingo)
# - Mes fecha orden = Mes del año que se realizo la orden
# - semana del año orden = Semana del año que se hizo la orden
# - Usuario aprobador = Usuario que aprueba la orden
# - Categoría = categoría del item que se ordena
# ### Variable objetivo
# - dias para aprobación = Fecha aprobacion - fecha orden

# %%
variables=df[[ 'dia fecha orden',
       'mes fecha orden', 'semana del año orden','dias para aprobación','USUARIO APROBADOR','CATEGORÍA']]

# %%
variables=variables.dropna()

# %%
#Acomodando los datos para entrarlos al modelo
variables['semana del año orden']=variables['semana del año orden'].astype('float64')
variables['dias para aprobación']=variables['dias para aprobación'].astype('int64')

# %%
#Datos de entrenamiento y prueba
train,test=train_test_split(variables,train_size=0.7,random_state=1234)
print('entrenamiento: ',train.shape)
print('test: ',test.shape)
# Out:
# entrenamiento:  (14881, 6)
# test:  (6378, 6)

# %%
setup(train,target='dias para aprobación',
            train_size=0.7,
            preprocess=True,
            remove_multicollinearity=True,
            multicollinearity_threshold=0.8,
            numeric_features=['dia fecha orden',
                           'mes fecha orden','semana del año orden'],
            normalize=True,
            normalize_method='minmax',
      fold_shuffle=True
      
    
      
            );
# Out:
# <style type="text/css">
# #T_6c0c7_row27_col1, #T_6c0c7_row40_col1, #T_6c0c7_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_6c0c7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c0c7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6c0c7_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_6c0c7_row0_col1" class="data row0 col1" >5140</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6c0c7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_6c0c7_row1_col1" class="data row1 col1" >dias para aprobación</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6c0c7_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_6c0c7_row2_col1" class="data row2 col1" >(14881, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6c0c7_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_6c0c7_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6c0c7_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_6c0c7_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6c0c7_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_6c0c7_row5_col1" class="data row5 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6c0c7_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_6c0c7_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6c0c7_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_6c0c7_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6c0c7_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_6c0c7_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6c0c7_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_6c0c7_row9_col1" class="data row9 col1" >(10416, 101)</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_6c0c7_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_6c0c7_row10_col1" class="data row10 col1" >(4465, 101)</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_6c0c7_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_6c0c7_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_6c0c7_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_6c0c7_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_6c0c7_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_6c0c7_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_6c0c7_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_6c0c7_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_6c0c7_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_6c0c7_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_6c0c7_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_6c0c7_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_6c0c7_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_6c0c7_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_6c0c7_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_6c0c7_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_6c0c7_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_6c0c7_row19_col1" class="data row19 col1" >92f7</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_6c0c7_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_6c0c7_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_6c0c7_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_6c0c7_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_6c0c7_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_6c0c7_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_6c0c7_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_6c0c7_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_6c0c7_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_6c0c7_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_6c0c7_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_6c0c7_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_6c0c7_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_6c0c7_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_6c0c7_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_6c0c7_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_6c0c7_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_6c0c7_row28_col1" class="data row28 col1" >minmax</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_6c0c7_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_6c0c7_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c7_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_6c0c7_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_6c0c7_row30_c

# %%
compare_models(fold=10,sort='RMSE')
# Out:
# <style type="text/css">
# #T_b6df0_ th {
#   text-align: left;
# }
# #T_b6df0_row0_col0, #T_b6df0_row0_col1, #T_b6df0_row0_col6, #T_b6df0_row1_col0, #T_b6df0_row1_col1, #T_b6df0_row1_col2, #T_b6df0_row1_col3, #T_b6df0_row1_col4, #T_b6df0_row1_col5, #T_b6df0_row2_col0, #T_b6df0_row2_col1, #T_b6df0_row2_col2, #T_b6df0_row2_col3, #T_b6df0_row2_col4, #T_b6df0_row2_col5, #T_b6df0_row2_col6, #T_b6df0_row3_col0, #T_b6df0_row3_col1, #T_b6df0_row3_col2, #T_b6df0_row3_col3, #T_b6df0_row3_col4, #T_b6df0_row3_col5, #T_b6df0_row3_col6, #T_b6df0_row4_col0, #T_b6df0_row4_col2, #T_b6df0_row4_col3, #T_b6df0_row4_col4, #T_b6df0_row4_col5, #T_b6df0_row5_col0, #T_b6df0_row5_col1, #T_b6df0_row5_col2, #T_b6df0_row5_col3, #T_b6df0_row5_col4, #T_b6df0_row5_col5, #T_b6df0_row5_col6, #T_b6df0_row6_col0, #T_b6df0_row6_col1, #T_b6df0_row6_col2, #T_b6df0_row6_col3, #T_b6df0_row6_col4, #T_b6df0_row6_col5, #T_b6df0_row6_col6, #T_b6df0_row7_col0, #T_b6df0_row7_col1, #T_b6df0_row7_col2, #T_b6df0_row7_col3, #T_b6df0_row7_col4, #T_b6df0_row7_col5, #T_b6df0_row7_col6, #T_b6df0_row8_col0, #T_b6df0_row8_col1, #T_b6df0_row8_col2, #T_b6df0_row8_col3, #T_b6df0_row8_col4, #T_b6df0_row8_col5, #T_b6df0_row8_col6, #T_b6df0_row9_col0, #T_b6df0_row9_col1, #T_b6df0_row9_col2, #T_b6df0_row9_col3, #T_b6df0_row9_col4, #T_b6df0_row9_col5, #T_b6df0_row9_col6, #T_b6df0_row10_col0, #T_b6df0_row10_col1, #T_b6df0_row10_col2, #T_b6df0_row10_col3, #T_b6df0_row10_col4, #T_b6df0_row10_col5, #T_b6df0_row10_col6, #T_b6df0_row11_col0, #T_b6df0_row11_col1, #T_b6df0_row11_col2, #T_b6df0_row11_col3, #T_b6df0_row11_col4, #T_b6df0_row11_col5, #T_b6df0_row11_col6, #T_b6df0_row12_col0, #T_b6df0_row12_col1, #T_b6df0_row12_col2, #T_b6df0_row12_col3, #T_b6df0_row12_col4, #T_b6df0_row12_col5, #T_b6df0_row12_col6, #T_b6df0_row13_col0, #T_b6df0_row13_col1, #T_b6df0_row13_col2, #T_b6df0_row13_col3, #T_b6df0_row13_col4, #T_b6df0_row13_col5, #T_b6df0_row13_col6, #T_b6df0_row14_col0, #T_b6df0_row14_col1, #T_b6df0_row14_col2, #T_b6df0_row14_col3, #T_b6df0_row14_col4, #T_b6df0_row14_col5, #T_b6df0_row14_col6, #T_b6df0_row15_col0, #T_b6df0_row15_col1, #T_b6df0_row15_col2, #T_b6df0_row15_col3, #T_b6df0_row15_col4, #T_b6df0_row15_col5, #T_b6df0_row15_col6, #T_b6df0_row16_col0, #T_b6df0_row16_col1, #T_b6df0_row16_col2, #T_b6df0_row16_col3, #T_b6df0_row16_col4, #T_b6df0_row16_col5, #T_b6df0_row16_col6, #T_b6df0_row17_col0, #T_b6df0_row17_col1, #T_b6df0_row17_col2, #T_b6df0_row17_col3, #T_b6df0_row17_col4, #T_b6df0_row17_col5, #T_b6df0_row17_col6, #T_b6df0_row18_col0, #T_b6df0_row18_col1, #T_b6df0_row18_col2, #T_b6df0_row18_col3, #T_b6df0_row18_col4, #T_b6df0_row18_col5, #T_b6df0_row18_col6 {
#   text-align: left;
# }
# #T_b6df0_row0_col2, #T_b6df0_row0_col3, #T_b6df0_row0_col4, #T_b6df0_row0_col5, #T_b6df0_row1_col6, #T_b6df0_row4_col1, #T_b6df0_row4_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_b6df0_row0_col7, #T_b6df0_row1_col7, #T_b6df0_row2_col7, #T_b6df0_row3_col7, #T_b6df0_row4_col7, #T_b6df0_row5_col7, #T_b6df0_row6_col7, #T_b6df0_row7_col7, #T_b6df0_row8_col7, #T_b6df0_row9_col7, #T_b6df0_row10_col7, #T_b6df0_row11_col7, #T_b6df0_row12_col7, #T_b6df0_row13_col7, #T_b6df0_row14_col7, #T_b6df0_row15_col7, #T_b6df0_row16_col7, #T_b6df0_row18_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_b6df0_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_b6df0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6df0_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_b6df0_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_b6df0_row0_col1" class="data row0 col1" >0.2906</td>
#       <td id="T_b6df0_row0_col2" class="data row0 col2" >0.6366</td>
#       <td id="T_b6df0_row0_col3" class="data row0 col3" >0.7959</td>
#       <td id="T_b6df0_row0_col4" class="data row0 col4" >0.9292</td>
#       <td id="T_b6df0_row0_col5" class="data row0 col5" >0.2825</td>
#       <td id="T_b6df0_row0_col6" class="data row0 col6" >0.1788</td>
#       <td id="T_b6df0_row0_col7" class="data row0 col7" >0.4670</td>
#     </tr>
#     <tr>
#       <th id="T_b6df0_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_b6df0_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#       <td id="T_b6df0_row1_col1" class="data row1 col1" >0.2815</td>
#       <td id="T_b6df0_row1_col2" class="data row1 col2" >0.6970</td>
#       <td id="T_b6df0_row1_col3" class="data row1 col3" >0.8318</td>
#       <td id="T_b6df0_row1_col4" class="data row1 col4" >0.9225</td>
#       <td id="T_b6df0_row1_col5" class="data row1 col5" >0.2912</td>
#       <td id="T_b6df0_row1_col6" class="data row1 col6" >0.1750</td>
#       <td id="T_b6df0_row1_col7" class="data row1 col7" >0.5840</td>
#     </tr>
#     <tr>
#       <th id="T_b6df0_level0_row2" class="row_heading level0 row2" >catboost</th>
#       <td id="T_b6df0_row2_col0" class="data row2 col0" >CatBoost Regressor</td>
#       <td id="T_b6df0_row2_col1" class="data row2 col1" >0.4104</td>
#       <td id="T_b6df0_row2_col2" class="data row2 col2" >0.6940</td>
#       <td id="T_b6df0_row2_col3" class="data row2 col3" >0.8321</td>
#       <td id="T_b6df0_row2_col4" class="data row2 col4" >0.9227</td>
#       <td id="T_b6df0_row2_col5" class="data row2 col5" >0.3125</td>
#       <td id="T_b6df0_row2_col6" class="data row2 col6" >0.2408</td>
#       <td id="T_b6df0_row2_col7" class="data row2 col7" >0.7280</td>
#     </tr>
#     <tr>
#       <th id="T_b6df0_level0_row3" class="row_heading level0 row3" >xgboost</th>
#       <td id="T_b6df0_row3_col0" class="data row3 col0" >Extreme Gradient Boosting</td>
#       <td id="T_b6df0_row3_col1" class="data row3 col1" >0.3795</td>
#       <td id="T_b6df0_row3_col2" class="data row3 col2" >0.6954</td>
#       <td id="T_b6df0_row3_col3" class="data row3 col3" >0.8327</td>
#       <td id="T_b6df0_row3_col4" class="data row3 col4" >0.9226</td>
#       <td id="T_b6df0_row3_col5" class="data row3 col5" >0.3075</td>
#       <td id="T_b6df0_row3_col6" class="data row3 col6" >0.2274</td>
#       <td id="T_b6df0_row3_col7" class="data row3 col7" >0.6240</td>
#     </tr>
#     <tr>
#       <th id="T_b6df0_level0_row4" class="row_heading level0 row4" >dt</th>
#       <td id="T_b6df0_row4_col0" class="data row4 col0" >Decision Tree Regressor</td>
#       <td id="T_b6df0_row4_col1" class="data row4 col1" >0.2763</td>
#       <td id="T_b6df0_row4_col2" class="data row4 col2" >0.7382</td>
#       <td id="T_b6df0_row4_col3" class="data row4 col3" >0.8548</td>
#       <td id="T_b6df0_row4_col4" class="data row4 col4" >0.9180</td>
#       <td id="T_b6df0_row4_col5" class="data row4 col5" >0.2962</td>
#       <td id="T_b6df0_row4_col6" class="data row4 col6" >0.1750</td>
#       <td id="T_b6df0_row4_col7" class="data row4 col7" >0.0250</td>
#     </tr>
#     <tr>
#       <th id="T_b6df0_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_b6df0_row5_col0" class="data row5 col0" >K Neighbors Regressor</td>
#       <td id="T_b6df0_row5_col1" class="data row5 col1" >0.3402</td>
#       <td id="T_b6df0_row5_col2" class="data row5 col2" >0.7649</td>
#       <td id="T_b6df0_row5_col3" class="data row5 col3" >0.8723</td>
#       <td id="T_b6df0_row5_col4" class="data row5 col4" >0.9149</td>
#       <td id="T_b6df0_row5_col5" class="data row5 col5" >0.3173</td>
#       <td id="T_b6df0_row5_col6" class="data row5 col6" >0.2111</td>
#       <td id="T_b6df0_row5_col7" class="data row5 col7" >0.1170</td>
#     </tr>
#     <tr>
#       <th id="T_b6df0_level0_row6" class="row_heading level0 row6" >
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=-1, oob_score=False,
#                       random_state=5140, verbose=0, warm_start=False)

# %%
#Elección de modelo
final_model=create_model('rf')
# Out:
# <style type="text/css">
# #T_1d7e8_row10_col0, #T_1d7e8_row10_col1, #T_1d7e8_row10_col2, #T_1d7e8_row10_col3, #T_1d7e8_row10_col4, #T_1d7e8_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_1d7e8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1d7e8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1d7e8_row0_col0" class="data row0 col0" >0.3065</td>
#       <td id="T_1d7e8_row0_col1" class="data row0 col1" >0.7088</td>
#       <td id="T_1d7e8_row0_col2" class="data row0 col2" >0.8419</td>
#       <td id="T_1d7e8_row0_col3" class="data row0 col3" >0.9178</td>
#       <td id="T_1d7e8_row0_col4" class="data row0 col4" >0.2997</td>
#       <td id="T_1d7e8_row0_col5" class="data row0 col5" >0.1819</td>
#     </tr>
#     <tr>
#       <th id="T_1d7e8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1d7e8_row1_col0" class="data row1 col0" >0.2851</td>
#       <td id="T_1d7e8_row1_col1" class="data row1 col1" >0.6604</td>
#       <td id="T_1d7e8_row1_col2" class="data row1 col2" >0.8127</td>
#       <td id="T_1d7e8_row1_col3" class="data row1 col3" >0.9277</td>
#       <td id="T_1d7e8_row1_col4" class="data row1 col4" >0.2795</td>
#       <td id="T_1d7e8_row1_col5" class="data row1 col5" >0.1749</td>
#     </tr>
#     <tr>
#       <th id="T_1d7e8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1d7e8_row2_col0" class="data row2 col0" >0.2612</td>
#       <td id="T_1d7e8_row2_col1" class="data row2 col1" >0.5386</td>
#       <td id="T_1d7e8_row2_col2" class="data row2 col2" >0.7339</td>
#       <td id="T_1d7e8_row2_col3" class="data row2 col3" >0.9392</td>
#       <td id="T_1d7e8_row2_col4" class="data row2 col4" >0.2669</td>
#       <td id="T_1d7e8_row2_col5" class="data row2 col5" >0.1740</td>
#     </tr>
#     <tr>
#       <th id="T_1d7e8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1d7e8_row3_col0" class="data row3 col0" >0.3091</td>
#       <td id="T_1d7e8_row3_col1" class="data row3 col1" >0.7453</td>
#       <td id="T_1d7e8_row3_col2" class="data row3 col2" >0.8633</td>
#       <td id="T_1d7e8_row3_col3" class="data row3 col3" >0.9163</td>
#       <td id="T_1d7e8_row3_col4" class="data row3 col4" >0.2844</td>
#       <td id="T_1d7e8_row3_col5" class="data row3 col5" >0.1925</td>
#     </tr>
#     <tr>
#       <th id="T_1d7e8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1d7e8_row4_col0" class="data row4 col0" >0.2764</td>
#       <td id="T_1d7e8_row4_col1" class="data row4 col1" >0.5324</td>
#       <td id="T_1d7e8_row4_col2" class="data row4 col2" >0.7297</td>
#       <td id="T_1d7e8_row4_col3" class="data row4 col3" >0.9403</td>
#       <td id="T_1d7e8_row4_col4" class="data row4 col4" >0.2571</td>
#       <td id="T_1d7e8_row4_col5" class="data row4 col5" >0.1899</td>
#     </tr>
#     <tr>
#       <th id="T_1d7e8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1d7e8_row5_col0" class="data row5 col0" >0.2930</td>
#       <td id="T_1d7e8_row5_col1" class="data row5 col1" >0.6309</td>
#       <td id="T_1d7e8_row5_col2" class="data row5 col2" >0.7943</td>
#       <td id="T_1d7e8_row5_col3" class="data row5 col3" >0.9293</td>
#       <td id="T_1d7e8_row5_col4" class="data row5 col4" >0.2889</td>
#       <td id="T_1d7e8_row5_col5" class="data row5 col5" >0.1897</td>
#     </tr>
#     <tr>
#       <th id="T_1d7e8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1d7e8_row6_col0" class="data row6 col0" >0.3347</td>
#       <td id="T_1d7e8_row6_col1" class="data row6 col1" >0.7640</td>
#       <td id="T_1d7e8_row6_col2" class="data row6 col2" >0.8741</td>
#       <td id="T_1d7e8_row6_col3" class="data row6 col3" >0.9216</td>
#       <td id="T_1d7e8_row6_col4" class="data row6 col4" >0.2915</td>
#       <td id="T_1d7e8_row6_col5" class="data row6 col5" >0.1825</td>
#     </tr>
#     <tr>
#       <th id="T_1d7e8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1d7e8_row7_col0" class="data row7 col0" >0.2512</td>
#       <td id="T_1d7e8_row7_col1" class="data row7 col1" >0.4951</td>
#       <td id="T_1d7e8_row7_col2" class="data row7 col2" >0.7036</td>
#       <td id="T_1d7e8_row7_col3" class="data row7 col3" >0.9445</td>
#       <td id="T_1d7e8_row7_col4" class="data row7 col4" >0.2792</td>
#       <td id="T_1d7e8_row7_col5" class="data row7 col5" >0.1475</td>
#     </tr>
#     <tr>
#       <th id="T_1d7e8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1d7e8_row8_col0" class="data row8 col0" >0.2780</td>
#       <td id="T_1d7e8_row8_col1" class="data row8 col1" >0.6018</td>
#       <td id="T_1d7e8_row8_col2" class="data row8 col2" >0.7758</td>
#       <td id="T_1d7e8_row8_col3" class="data row8 col3" >0.9352</td>
#       <td id="T_1d7e8_row8_col4" class="data row8 col4" >0.2818</td>
#       <td id="T_1d7e8_row8_col5" class="data row8 col5" >0.1679</td>
#     </tr>
#     <tr>
#       <th id="T_1d7e8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1d7e8_row9_col0" class="data row9 col0" >0.3103</td>
#       <td id="T_1d7e8_row9_col1" class="data row9 col1" >0.6887</td>
#       <td id="T_1d7e8_row9_col2" class="data row9 col2" >0.8299</td>
#       <td id="T_1d7e8_row9_col3" class="data row9 col3" >0.9202</td>
#       <td id="T_1d7e8_row9_col4" class="data row9 col4" >0.2962</td>
#       <td id="T_1d7e8_row9_col5" class="data row9 col5" >0.1871</td>
#     </tr>
#     <tr>
#       <th id="T_1d7e8_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_1d7e8_row10_col0" class="data row10 col0" >0.2906</td>
#       <td id="T_1d7e8_row10_col1" class="data row10 col1" >0.6366</td>
#       <td id="T_1d7e8_row10_col2" class="data row10 col2" >0.7959</td>
#       <td id="T_1d7e8_row10_col3" class="data row10 col3" >0.9292</td>
#       <td id="T_1d7e8_row10_col4" class="data row10 col4" >0.2825</td>
#       <td id="T_1d7e8_row10_col5" class="data row10 col5" >0.1788</td>
#     </tr>
#     <tr>
#       <th id="T_1d7e8_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_1d7e8_row11_col0" class="data row11 col0" >0.0240</td>
#       <td id="T_1d7e8_row11_col1" class="data row11 col1" >0.0885</td>
#       <td id="T_1d7e8_row11_col2" class="data row11 col2" >0.0560</td>
#       <td id="T_1d7e8_row11_col3" class="data row11 col3" >0.0097</td>
#       <td id="T_1d7e8_row11_col4" class="data row11 col4" >0.0123</td>
#       <td id="T_1d7e8_row11_col5" class="data row11 col5" >0.0129</td>
#     </tr>
#   </tbody>
# </table>

# %%
tune_rf=tune_model(estimator=final_model,optimize='RMSE',fold=5)
tune_rf
# Out:
# IntProgress(value=0, description='Processing: ', max=7)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   18:57:01
# Status     . . . . . . . . . . . . . . . . . .  Searching Hyperparameters
# Estimator  . . . . . . . . . . . . . . . . . .    Random Forest Regressor
# Empty DataFrame
# Columns: [MAE, MSE, RMSE, R2, RMSLE, MAPE]
# Index: []
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 tasks      | elapsed:  4.2min

# %%
plot_model(final_model,plot='learning')

# %%
plot_model(tune_rf,plot='learning')

# %%
plot_model(final_model,plot='feature')

# %%
plot_model(tune_rf,plot='feature')

# %%
plot_model(final_model,plot='residuals')

# %%
plot_model(tune_rf,plot='residuals')

# %%
predicciones=predict_model(final_model,data=test,round=0)
predicciones[['dias para aprobación','Label']].head(5)
# Out:
#        dias para aprobación     Label
# 22335                     0  0.000000
# 22752                     1  0.171565
# 10442                     1  0.285404
# 17978                     7  7.000000
# 12963                     7  7.000000

# %%
predicciones
# Out:
#        dia fecha orden  mes fecha orden  semana del año orden  \
# 22335                3                6                  25.0
# 22752                0                5                  22.0
# 10442                4               12                  49.0
# 17978                3               11                  48.0
# 12963                0                2                   8.0
# ...                ...              ...                   ...
# 2122                 4                9                  35.0
# 21874                0                7                  30.0
# 2847                 2                8                  32.0
# 16998                5               11                  48.0
# 15284                4               12                  50.0
#
#        dias para aprobación     USUARIO APROBADOR  \
# 22335                     0  Usuario Aprobador 66
# 22752                     1  Usuario Aprobador 66
# 10442                     1   Usuario Aprobador 4
# 17978                     7  Usuario Aprobador 60
# 12963                     7  Usuario Aprobador 60
# ...                     ...                   ...
# 2122                      0   Usuario Aprobador 6
# 21874                     0  Usuario Aprobador 67
# 2847                      0   Usuario Aprobador 1
# 16998                     7  Usuario Aprobador 60
# 15284                     7  Usuario Aprobador 60
#
#                                CATEGORÍA     Label
# 22335                Alimentos y Bebidas  0.000000
# 22752                Alimentos y Bebidas  0.171565
# 10442                Alimentos y Bebidas  0.285404
# 17978  Vigilancia y seguridad industrial  7.000000
# 12963  Vigilancia y seguridad industrial  7.000000
# ...                                  ...       ...
# 2122                          Ferreteria  0.010000
# 21874          Aseo, Cafetería y Oficina  0.000000
# 2847                          Ferreteria  0.000000
# 16998  Vigilancia y seguridad industrial  7.000000
# 15284  Vigilancia y seguridad industrial  7.000000
#
# [6378 rows x 7 columns]

# %%
from sklearn.metrics import mean_squared_error,r2_score,median_absolute_error,explained_variance_score
mse=mean_squared_error(predicciones['dias para aprobación'],predicciones['Label'])
r2=r2_score(predicciones['dias para aprobación'],predicciones['Label'])
mae=median_absolute_error(predicciones['dias para aprobación'],predicciones['Label'])
explain_variance=explained_variance_score(predicciones['dias para aprobación'],predicciones['Label'])
print('MSE: ',mse)
print('RMSE: ',np.sqrt(mse))
print('R2: ',r2)
print('MAE: ',mae)
# Out:
# MSE:  0.6596350642129536
# RMSE:  0.8121792069567858
# R2:  0.9255222342468211
# MAE:  0.0

# %%
df.columns
# Out:
# Index(['NÚMERO PEDIDO', 'ORDEN NÚMERO', 'FECHA ORDEN', 'FECHA ENTREGA',
#        'FECHA APROBACION', 'CATEGORÍA', 'SUBCATEGORIA', 'PROVEEDOR', 'USUARIO',
#        'USUARIO APROBADOR', 'DIRECCION PEDIDO', 'DIRECCION FACTURACION',
#        'PORTAL', 'ESTADO', 'PRODUCTO O SERVICIO', 'CODIGO PORTAL',
#        'CANTIDAD PEDIDA', 'PRECIO UNITARIO', 'PRECIO UNITARIO + IVA', 'IVA',
#        'TOTAL SIN IVA', 'TOTAL + IVA', 'FECHA ULTIMO MOVIMIENTO',
#        'dia fecha aprobacion', 'mes fecha aprobacion',
#        'semana del año aprobacion', 'dia fecha orden', 'mes fecha orden',
#        'semana del año orden', 'dias para aprobación'],
#       dtype='object')

# %%
bd_nueva=df[['USUARIO',
       'USUARIO APROBADOR','CATEGORÍA','PROVEEDOR']]
bd_nueva.to_excel('bd_nueva.xlsx')

# %%
prediccionesE=predict_model(tune_rf,data=test,round=0)
mse=mean_squared_error(prediccionesE['dias para aprobación'],prediccionesE['Label'])
r2=r2_score(prediccionesE['dias para aprobación'],prediccionesE['Label'])
mae=median_absolute_error(prediccionesE['dias para aprobación'],prediccionesE['Label'])
explain_variance=explained_variance_score(prediccionesE['dias para aprobación'],prediccionesE['Label'])
print('MSE: ',mse)
print('RMSE: ',np.sqrt(mse))
print('R2: ',r2)
print('MAE: ',mae)

# %%
#save_model(final_model,'modelo_final',)
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=['dia fecha orden',
#                                                            'mes fecha orden',
#                                                            'semana del año '
#                                                            'orden'],
#                                        target='dias para aprobación',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_v...
#                   RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                         criterion='mse', max_depth=None,
#                                         max_features='auto', max_leaf_nodes=None,
#                                         max_samples=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         n_estimators=100, n_jobs=-1,
#                                         oob_score=False, random_state=5140,
#                                         verbose=0, warm_start=False)]],
#           verbose=False),
#  'modelo_final.pkl')

# %%
batche_prueba=df[['NÚMERO PEDIDO','ORDEN NÚMERO','FECHA ORDEN','CATEGORÍA','PRODUCTO O SERVICIO','CANTIDAD PEDIDA','USUARIO','USUARIO APROBADOR']].iloc[1:200,:]
batche_prueba.to_excel('batche_prueba.xlsx')

# %%
batche_prueba
# Out:
#     NÚMERO PEDIDO ORDEN NÚMERO FECHA ORDEN                  CATEGORÍA  \
# 1         # 49560       # 2581  2021-11-10      Mercadeo y publicidad
# 2         # 49559       # 2580  2021-11-10        Alimentos y Bebidas
# 3         # 49558       # 1892  2021-11-10        Alimentos y Bebidas
# 4         # 49557          # 1  2021-11-10      Imprenta y litografía
# 5         # 49556        # 508  2021-11-10          Gestión ambiental
# ..            ...          ...         ...                        ...
# 195       # 49466       # 2505  2021-11-05                 Ferreteria
# 196       # 49466       # 2505  2021-11-05                 Ferreteria
# 197       # 49465       # 2504  2021-11-05        Alimentos y Bebidas
# 198       # 49464        # 504  2021-11-05        Alimentos y Bebidas
# 199       # 49463       # 2503  2021-11-05  Aseo, Cafetería y Oficina
#
#                                 PRODUCTO O SERVICIO  CANTIDAD PEDIDA  \
# 1                           ACTIVIDADES COMERCIALES              1.0
# 2                                           Lasagna             10.0
# 3                     Pecho de Res Limpio/Sin Grasa             50.0
# 4                     LIBRO CABEZA, CORAZON Y MANOS              7.0
# 5                Recoleccion de residuos ordinarios             29.0
# ..                                              ...              ...
# 195                              RODILLO GOYA DE 3"              1.0
# 196                         ANTICORROSIVO GRIS 1/4               1.0
# 197                                   Bandeja paisa              4.0
# 198  Refrigerio Croissant de jamón con queso 100 gr             13.0
# 199                    BOLIGRAFO OFFI-ESCO RET AZUL             10.0
#
#                     USUARIO    USUARIO APROBADOR
# 1     Usuario solicitante 2  Usuario Aprobador 2
# 2     Usuario solicitante 3  Usuario Aprobador 3
# 3     Usuario solicitante 4  Usuario Aprobador 4
# 4     Usuario solicitante 5  Usuario Aprobador 5
# 5     Usuario solicitante 6                  NaN
# ..                      ...                  ...
# 195   Usuario solicitante 1  Usuario Aprobador 1
# 196   Usuario solicitante 1  Usuario Aprobador 1
# 197   Usuario solicitante 3  Usuario Aprobador 3
# 198  Usuario solicitante 27  Usuario Aprobador 9
# 199   Usuario solicitante 9  Usuario Aprobador 3
#
# [199 rows x 8 columns]
