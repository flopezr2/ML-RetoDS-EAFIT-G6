# %%
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_excel('Ordenes de compra PORTAL 1K.xlsx')
data.head(3)
# Out:
#   NÚMERO PEDIDO ORDEN NÚMERO  ... TOTAL + IVA FECHA ULTIMO MOVIMIENTO
# 0       # 49561       # 2582  ...      55.606              2021-11-10
# 1       # 49560       # 2581  ...   1.757.597              2021-11-10
# 2       # 49559       # 2580  ...     155.000              2021-11-10
#
# [3 rows x 26 columns]

# %%
data.shape
# Out:
# (23083, 26)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23083 entries, 0 to 23082
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   NÚMERO PEDIDO            23083 non-null  object
#  1   ORDEN NÚMERO             23083 non-null  object
#  2   FECHA ORDEN              23083 non-null  object
#  3   FECHA ENTREGA            18770 non-null  object
#  4   FECHA APROBACION         21950 non-null  object
#  5   CATEGORÍA                23083 non-null  object
#  6   SUBCATEGORIA             23083 non-null  object
#  7   PROVEEDOR                23083 non-null  object
#  8   USUARIO                  23083 non-null  object
#  9   USUARIO APROBADOR        21950 non-null  object
#  10  DIRECCION PEDIDO         23083 non-null  object
#  11  DIRECCION FACTURACION    10828 non-null  object
#  12  CENTRO DE COSTOS         16672 non-null  object
#  13  PRESUPUESTO              18581 non-null  object
# ...

# %%
data.isnull().sum()
# Out:
# NÚMERO PEDIDO                  0
# ORDEN NÚMERO                   0
# FECHA ORDEN                    0
# FECHA ENTREGA               4313
# FECHA APROBACION            1133
# CATEGORÍA                      0
# SUBCATEGORIA                   0
# PROVEEDOR                      0
# USUARIO                        0
# USUARIO APROBADOR           1133
# DIRECCION PEDIDO               0
# DIRECCION FACTURACION      12255
# CENTRO DE COSTOS            6411
# PRESUPUESTO                 4502
# PORTAL                         0
# ESTADO                         0
# PRODUCTO O SERVICIO            0
# CODIGO PORTAL               4860
# CANTIDAD PEDIDA                0
# CANTIDAD RECIBIDA           7070
# PRECIO UNITARIO                0
# PRECIO UNITARIO + IVA          0
# IVA                            0
# TOTAL SIN IVA                  0
# TOTAL + IVA                    0
# FECHA ULTIMO MOVIMIENTO        0
# dtype: int64

# %%
null_data= data.isna().sum()
nulos_data=null_data[null_data!=0]
nulos_data
# Out:
# FECHA ENTREGA             4313
# FECHA APROBACION          1133
# USUARIO APROBADOR         1133
# DIRECCION FACTURACION    12255
# CENTRO DE COSTOS          6411
# PRESUPUESTO               4502
# CODIGO PORTAL             4860
# CANTIDAD RECIBIDA         7070
# dtype: int64

# %%
DF_nulos = pd.DataFrame([nulos_data,100*(nulos_data/23083)],index=["Cantidad de Nulos","Porcentaje de Nulos"]).T
DF_nulos
# Out:
#                        Cantidad de Nulos  Porcentaje de Nulos
# FECHA ENTREGA                     4313.0            18.684746
# FECHA APROBACION                  1133.0             4.908374
# USUARIO APROBADOR                 1133.0             4.908374
# DIRECCION FACTURACION            12255.0            53.091019
# CENTRO DE COSTOS                  6411.0            27.773686
# PRESUPUESTO                       4502.0            19.503531
# CODIGO PORTAL                     4860.0            21.054456
# CANTIDAD RECIBIDA                 7070.0            30.628601

# %%
data.duplicated().sum()
# Out:
# 691

# %%
data.describe()
# Out:
#        CANTIDAD PEDIDA  CANTIDAD RECIBIDA
# count     23083.000000       16013.000000
# mean        191.208232          69.835325
# std        1946.639150        1040.933380
# min           0.270000           0.000000
# 25%           2.000000           2.000000
# 50%           7.000000           5.000000
# 75%          40.000000          18.000000
# max      120000.000000       53620.000000

# %%
plt.figure(figsize=(10,20))
eje_x = data['CATEGORÍA'] 
eje_y = data['CANTIDAD PEDIDA']
plt.barh(eje_x, eje_y)
plt.ylabel('CATEGORÍA')
plt.xlabel('CANTIDAD PEDIDA')
plt.title('CANTIDAD PEDIDA POR CATEGORÍA')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(data['CANTIDAD PEDIDA'], bins=15)
plt.ylabel('FRECUENCIA')
plt.xlabel('CANTIDAD PEDIDA')
plt.title('FRECUENCIA DE CANTIDAD PEDIDA')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.hist(data['CANTIDAD RECIBIDA'], bins=15)
plt.ylabel('FRECUENCIA')
plt.xlabel('CANTIDAD RECIBIDA')
plt.title('FRECUENCIA DE CANTIDAD RECIBIDA')
plt.show()
