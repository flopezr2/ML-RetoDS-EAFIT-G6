# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pl
import seaborn as sns
import missingno as msn
import os

# %%
df=pd.read_excel('C:\\Users\\Admin\\OneDrive\\Documentos\\DataScience2021-2\\Trabajos_propios_felipe\\Proyecto_final\\Ordenes de compra PORTAL 1K (datos completo).xlsx')

# %%
#Manejo inicial de base de datos
df.drop(labels=['Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28'],axis=1,inplace=True)
df.drop_duplicates(inplace=True)

#Cambiando formato de variables
df['FECHA ORDEN']=pd.to_datetime(df['FECHA ORDEN'],format='%Y-%m-%d',errors = 'coerce')
df['FECHA ENTREGA']=pd.to_datetime(df['FECHA ENTREGA'],format='%Y-%m-%d',errors = 'coerce')
df['FECHA APROBACION']=pd.to_datetime(df['FECHA APROBACION'],format='%Y-%m-%d',errors = 'coerce')
df['FECHA ULTIMO MOVIMIENTO']=pd.to_datetime(df['FECHA ULTIMO MOVIMIENTO'],format='%Y-%m-%d',errors = 'coerce')
df['PRECIO UNITARIO']=df['PRECIO UNITARIO'].apply(lambda x:float(x.replace('.','')))
df['PRECIO UNITARIO + IVA']=df['PRECIO UNITARIO + IVA'].apply(lambda x:float(x.replace('.','')))
df['IVA']=df['IVA'].apply(lambda x:float(x.replace('.','')))
df['TOTAL SIN IVA']=df['TOTAL SIN IVA'].apply(lambda x:float(x.replace('.','')))
df['TOTAL + IVA']=df['TOTAL + IVA'].apply(lambda x:float(x.replace('.','')))

#Eliminamos columnas que no usaremos
df.drop(labels=['CANTIDAD RECIBIDA','CENTRO DE COSTOS','PRESUPUESTO','DIRECCION FACTURACION',
               'FECHA ENTREGA','CODIGO PORTAL'],inplace=True,axis=1)

# %%
#Con las fechas de aprobacion
df['dia fecha aprobacion']=df['FECHA APROBACION'].dt.dayofweek #0 lunes, 6 domingo
df['mes fecha aprobacion']=df['FECHA APROBACION'].dt.month #Meses de aprobación 
df['semana del año aprobacion']=df['FECHA APROBACION'].dt.isocalendar().week

#Con las fechas de orden
df['dia fecha orden']=df['FECHA ORDEN'].dt.dayofweek #0 lunes, 6 domingo
df['mes fecha orden']=df['FECHA ORDEN'].dt.month #Meses de ordbación 
df['semana del año orden']=df['FECHA ORDEN'].dt.isocalendar().week
df['dias para aprobación']=(df['FECHA APROBACION']-df['FECHA ORDEN']).dt.days
df['dias proceso']=np.where((df['ESTADO']!='Cancelado')&(df['ESTADO']!='Orden en Proceso')&(df['ESTADO']!='Orden Rechazada'),
                            
                            (df['FECHA ULTIMO MOVIMIENTO']-df['FECHA APROBACION']).dt.days,np.nan)
pd.set_option('display.max_columns', None)

# %%
df['dias proceso'].describe()
# Out:
# count    15286.000000
# mean        10.446749
# std         21.894738
# min          0.000000
# 25%          0.000000
# 50%          2.000000
# 75%         11.000000
# max        229.000000
# Name: dias proceso, dtype: float64

# %%
df.shape
# Out:
# (22392, 28)

# %%
msn.matrix(df);

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (15286, 28)

# %%
df['dias proceso']=df['dias proceso'].astype('int64')

# %%
df.corr()['dias proceso'].T.sort_values(ascending=False)
# Out:
# dias proceso                 1.000000
# mes fecha aprobacion         0.200342
# semana del año aprobacion    0.196336
# dia fecha orden              0.028749
# CANTIDAD PEDIDA              0.000213
# PRECIO UNITARIO             -0.008197
# IVA                         -0.008214
# PRECIO UNITARIO + IVA       -0.008285
# TOTAL SIN IVA               -0.047664
# TOTAL + IVA                 -0.048979
# semana del año orden        -0.135717
# dia fecha aprobacion        -0.141138
# mes fecha orden             -0.142208
# dias para aprobación        -0.284325
# Name: dias proceso, dtype: float64

# %%
from scipy.stats import f_oneway
stat, p = f_oneway(*df.groupby('PROVEEDOR')['dias proceso'].apply(lambda x:list(x)))
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probable distribución igual')
else:
    print('Significancia estadistica, para distribuciones diferentes en dias proceso de proveedores')
# Out:
# stat=27.335, p=0.000
# Significancia estadistica, para distribuciones diferentes en dias proceso de proveedores

# %%
stat, p = f_oneway(*df.groupby('CATEGORÍA')['dias proceso'].apply(lambda x:list(x)))
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probable distribución igual')
else:
    print('Significancia estadistica, para distribuciones diferentes en dias proceso de las categorias')
# Out:
# stat=70.318, p=0.000
# Significancia estadistica, para distribuciones diferentes en dias proceso de las categorias

# %%
df.columns
# Out:
# Index(['NÚMERO PEDIDO', 'ORDEN NÚMERO', 'FECHA ORDEN', 'FECHA APROBACION',
#        'CATEGORÍA', 'SUBCATEGORIA', 'PROVEEDOR', 'USUARIO',
#        'USUARIO APROBADOR', 'DIRECCION PEDIDO', 'PORTAL', 'ESTADO',
#        'PRODUCTO O SERVICIO', 'CANTIDAD PEDIDA', 'PRECIO UNITARIO',
#        'PRECIO UNITARIO + IVA', 'IVA', 'TOTAL SIN IVA', 'TOTAL + IVA',
#        'FECHA ULTIMO MOVIMIENTO', 'dia fecha aprobacion',
#        'mes fecha aprobacion', 'semana del año aprobacion', 'dia fecha orden',
#        'mes fecha orden', 'semana del año orden', 'dias para aprobación',
#        'dias proceso'],
#       dtype='object')

# %%
stat, p = f_oneway(*df.groupby('USUARIO')['dias proceso'].apply(lambda x:list(x)))
print('stat=%.3f, p=%.3f' % (stat, p))
if p > 0.05:
    print('Probable distribución igual')
else:
    print('Significancia estadistica, para distribuciones diferentes  de  dias proceso de los usuarios')
# Out:
# stat=58.304, p=0.000
# Significancia estadistica, para distribuciones diferentes  de  dias proceso de los usuarios

# %%
df
# Out:
#       NÚMERO PEDIDO ORDEN NÚMERO FECHA ORDEN FECHA APROBACION  \
# 1           # 49560       # 2581  2021-11-10       2021-11-10
# 4           # 49557          # 1  2021-11-10       2021-11-10
# 12          # 49550       # 2574  2021-11-10       2021-11-10
# 13          # 49549       # 2573  2021-11-10       2021-11-10
# 34          # 49534       # 2561  2021-11-09       2021-11-09
# ...             ...          ...         ...              ...
# 23078           # 2          # 2  2018-04-30       2018-05-01
# 23079           # 2          # 2  2018-04-30       2018-05-01
# 23080           # 2          # 2  2018-04-30       2018-05-01
# 23081           # 1          # 1  2018-04-30       2018-04-30
# 23082           # 1          # 1  2018-04-30       2018-04-30
#
#                                CATEGORÍA  \
# 1                  Mercadeo y publicidad
# 4                  Imprenta y litografía
# 12                 Mercadeo y publicidad
# 13     Viajes, Eventos y Entretenimiento
# 34               Servicios Profesionales
# ...                                  ...
# 23078          Aseo, Cafetería y Oficina
# 23079          Aseo, Cafetería y Oficina
# 23080                  Moda y accesorios
# 23081                  Moda y accesorios
# 23082          Aseo, Cafetería y Oficina
#
#                                            SUBCATEGORIA      PROVEEDOR  \
# 1                                            Publicidad    Proveedor 2
# 4                                                  Otra    Proveedor 5
# 12                                           Publicidad    Proveedor 7
# 13                      Servicios de gestión de eventos    Proveedor 8
# 34     Asesoría y consultoría en producción y logística   Proveedor 17
# ...                                                 ...            ...
# 23078                            Elementos de papelería  Proveedor 229
# 23079                            Elementos de papelería  Proveedor 229
# 23080                                           Calzado  Proveedor 229
# 23081                                           Calzado  Proveedor 229
# 23082                            Elementos de papelería  Proveedor 229
#
#                        USUARIO     USUARIO APROBADOR DIRECCION PEDIDO  \
# 1        Usuario solicitante 2   Usuario Aprobador 2      Direccion 1
# 4        Usuario solicitante 5   Usuario Aprobador 5      Direccion 4
# 12       Usuario solicitante 2   Usuario Aprobador 2      Direccion 7
# 13       Usuario solicitante 2   Usuario Aprobador 2      Direccion 1
# 34       Usuario solicitante 2   Usuario Aprobador 2      Direccion 1
# ...                        ...                   ...              ...
# 23078  Usuario solicitante 131  Usuario Aprobador 70     Direccion 81
# 23079  Usuario solicitante 131  Usuario Aprobador 70     Direccion 81
# 23080  Usuario solicitante 131  Usuario Aprobador 70     Direccion 81
# 23081  Usuario solicitante 131  Usuario Aprobador 70     Direccion 81
# 23082  Usuario solicitante 131  Usuario Aprobador 70     Direccion 81
#
#                    PORTAL    ESTADO  \
# 1      Portal comprador 1  Recibido
# 4      Portal comprador 3  Recibido
# 12     Portal comprador 1  Recibido
# 13     Portal comprador 1  Recibido
# 34     Portal comprador 1  Recibido
# ...                   ...       ...
# 23078  Portal comprador 8  Recibido
# 23079  Portal comprador 8  Recibido
# 23080  Portal comprador 8  Recibido
# 23081  Portal comprador 8  Recibido
# 23082  Portal comprador 8  Recibido
#
#                                      PRODUCTO O SERVICIO  CANTIDAD PEDIDA  \
# 1                                ACTIVIDADES COMERCIALES              1.0
# 4                          LIBRO CABEZA, CORAZON Y MANOS              7.0
# 12     Publicidad en ascensores de unidades residenci...             60.0
# 13                               Coordinación de Eventos              6.0
# 34                                     ASESORIA DIGITAL               1.0
# ...                                                  ...              ...
# 23078                                          Grapadora              8.0
# 23079                                     Lapicero Negro              1.0
# 23080                                              Botas              3.0
# 23081                                              Botas              4.0
# 23082                                          Grapadora              5.0
#
#        PRECIO UNITARIO  PRECIO UNITARIO + IVA       IVA  TOTAL SIN IVA  \
# 1            1476972.0              1757597.0  280625.0      1476972.0
# 4              92084.0               109580.0   17496.0       644588.0
# 12             27000.0                32130.0    5130.0      1620000.0
# 13            190000.0               226100.0   36100.0      1140000.0
# 34           1790000.0              2130100.0  340100.0      1790000.0
# ...                ...                    ...       ...            ...
# 23078          33613.0                40000.0    6387.0       268908.0
# 23079            588.0                  700.0     112.0          588.0
# 23080          29412.0                35000.0    5588.0        88235.0
# 23081          29412.0                35000.0    5588.0       117647.0
# 23082          33613.0                40000.0    6387.0       168067.0
#
#        TOTAL + IVA FECHA ULTIMO MOVIMIENTO  dia fecha aprobacion  \
# 1        1757597.0              2021-11-10                   2.0
# 4         767060.0              2021-11-10                   2.0
# 12       1927800.0              2021-11-10                   2.0
# 13       1356600.0              2021-11-10                   2.0
# 34       2130100.0              2021-11-09                   1.0
# ...            ...                     ...                   ...
# 23078     320000.0              2018-05-01                   1.0
# 23079        700.0              2018-05-01                   1.0
# 23080     105000.0              2018-05-01                   1.0
# 23081     140000.0              2018-05-01                   0.0
# 23082     200000.0              2018-05-01                   0.0
#
#        mes fecha aprobacion  semana del año aprobacion  dia fecha orden  \
# 1                      11.0                         45                2
# 4                      11.0                         45                2
# 12                     11.0                         45                2
# 13                     11.0                         45                2
# 34                     11.0                         45                1
# ...                     ...                        ...              ...
# 23078                   5.0                         18                0
# 23079                   5.0                         18                0
# 23080                   5.0                         18                0
# 23081                   4.0                         18                0
# 23082                   4.0                         18                0
#
#        mes fecha orden  semana del año orden  dias para aprobación  \
# 1                   11                    45                   0.0
# 4                   11                    45                   0.0
# 12                  11                    45                   0.0
# 13                  11                    45                   0.0
# 34                  11                    45                   0.0
# ...                ...                   ...                   ...
# 23078                4                    18                   1.0
# 23079                4                    18                   1.0
# 23080                4                    18                   1.0
# 23081                4                    18                   0.0
# 23082                4                    18                   0.0
#
#        dias proceso
# 1                 0
# 4                 0
# 12                0
# 13                0
# 34                0
# ...             ...
# 23078             0
# 23079             0
# 23080             0
# 23081             1
# 23082             1
#
# [15286 rows x 28 columns]

# %% [markdown]
# # MODELO PROCESO DE DIAS

# %% [markdown]
# *VARIABLES*
# - mes fecha aprobacion
# - semana del año aprobacion
# - proveedor
# - Categoria
# - Usuario

# %%
from pycaret.regression import *
from sklearn.model_selection import train_test_split

# %%
df.columns
# Out:
# Index(['NÚMERO PEDIDO', 'ORDEN NÚMERO', 'FECHA ORDEN', 'FECHA APROBACION',
#        'CATEGORÍA', 'SUBCATEGORIA', 'PROVEEDOR', 'USUARIO',
#        'USUARIO APROBADOR', 'DIRECCION PEDIDO', 'PORTAL', 'ESTADO',
#        'PRODUCTO O SERVICIO', 'CANTIDAD PEDIDA', 'PRECIO UNITARIO',
#        'PRECIO UNITARIO + IVA', 'IVA', 'TOTAL SIN IVA', 'TOTAL + IVA',
#        'FECHA ULTIMO MOVIMIENTO', 'dia fecha aprobacion',
#        'mes fecha aprobacion', 'semana del año aprobacion', 'dia fecha orden',
#        'mes fecha orden', 'semana del año orden', 'dias para aprobación',
#        'dias proceso'],
#       dtype='object')

# %%
var=df[['mes fecha aprobacion','semana del año aprobacion','PROVEEDOR', 'USUARIO','CATEGORÍA','dias proceso']]

# %%
var['semana del año aprobacion']=var['semana del año aprobacion'].astype('float64')

# %%
#Datos de entrenamiento y prueba
train,test=train_test_split(var,train_size=0.7,random_state=1888)
print('entrenamiento: ',train.shape)
print('test: ',test.shape)
# Out:
# entrenamiento:  (10700, 6)
# test:  (4586, 6)

# %%
setup(train,target='dias proceso',
            train_size=0.7,
            preprocess=True,
            remove_multicollinearity=True,
            multicollinearity_threshold=0.8,
           # remove_outliers=True,
      #outliers_threshold=0.10,
      #categorical_features=['mes fecha aprobacion','semana del año aprobacion','PROVEEDOR', 'USUARIO','CATEGORÍA'],
      normalize=True,
      normalize_method='minmax',
      
      
            );
# Out:
# <style type="text/css">
# #T_166a9_row27_col1, #T_166a9_row40_col1, #T_166a9_row42_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_166a9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_166a9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_166a9_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_166a9_row0_col1" class="data row0 col1" >577</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_166a9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_166a9_row1_col1" class="data row1 col1" >dias proceso</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_166a9_row2_col0" class="data row2 col0" >Original Data</td>
#       <td id="T_166a9_row2_col1" class="data row2 col1" >(10700, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_166a9_row3_col0" class="data row3 col0" >Missing Values</td>
#       <td id="T_166a9_row3_col1" class="data row3 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_166a9_row4_col0" class="data row4 col0" >Numeric Features</td>
#       <td id="T_166a9_row4_col1" class="data row4 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_166a9_row5_col0" class="data row5 col0" >Categorical Features</td>
#       <td id="T_166a9_row5_col1" class="data row5 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_166a9_row6_col0" class="data row6 col0" >Ordinal Features</td>
#       <td id="T_166a9_row6_col1" class="data row6 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_166a9_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#       <td id="T_166a9_row7_col1" class="data row7 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_166a9_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#       <td id="T_166a9_row8_col1" class="data row8 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_166a9_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#       <td id="T_166a9_row9_col1" class="data row9 col1" >(7489, 294)</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_166a9_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#       <td id="T_166a9_row10_col1" class="data row10 col1" >(3211, 294)</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_166a9_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#       <td id="T_166a9_row11_col1" class="data row11 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_166a9_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#       <td id="T_166a9_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_166a9_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_166a9_row13_col1" class="data row13 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_166a9_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_166a9_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_166a9_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_166a9_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_166a9_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_166a9_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_166a9_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_166a9_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_166a9_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_166a9_row18_col1" class="data row18 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_166a9_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_166a9_row19_col1" class="data row19 col1" >2067</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_166a9_row20_col0" class="data row20 col0" >Imputation Type</td>
#       <td id="T_166a9_row20_col1" class="data row20 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_166a9_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#       <td id="T_166a9_row21_col1" class="data row21 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_166a9_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#       <td id="T_166a9_row22_col1" class="data row22 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_166a9_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_166a9_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_166a9_row24_col0" class="data row24 col0" >Categorical Imputer</td>
#       <td id="T_166a9_row24_col1" class="data row24 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_166a9_row25_col0" class="data row25 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_166a9_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_166a9_row26_col0" class="data row26 col0" >Unknown Categoricals Handling</td>
#       <td id="T_166a9_row26_col1" class="data row26 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_166a9_row27_col0" class="data row27 col0" >Normalize</td>
#       <td id="T_166a9_row27_col1" class="data row27 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_166a9_row28_col0" class="data row28 col0" >Normalize Method</td>
#       <td id="T_166a9_row28_col1" class="data row28 col1" >minmax</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_166a9_row29_col0" class="data row29 col0" >Transformation</td>
#       <td id="T_166a9_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_166a9_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_166a9_row30_col0" class="data row30 col0" >Transformation Method</td>
#       <td id="T_166a9_row30_col1" class

# %%
compare_models(fold=10,sort='RMSE')
# Out:
# <style type="text/css">
# #T_838e8_ th {
#   text-align: left;
# }
# #T_838e8_row0_col0, #T_838e8_row0_col1, #T_838e8_row0_col6, #T_838e8_row1_col0, #T_838e8_row1_col1, #T_838e8_row1_col2, #T_838e8_row1_col3, #T_838e8_row1_col4, #T_838e8_row1_col5, #T_838e8_row1_col6, #T_838e8_row2_col0, #T_838e8_row2_col1, #T_838e8_row2_col2, #T_838e8_row2_col3, #T_838e8_row2_col4, #T_838e8_row2_col5, #T_838e8_row2_col6, #T_838e8_row3_col0, #T_838e8_row3_col2, #T_838e8_row3_col3, #T_838e8_row3_col4, #T_838e8_row3_col5, #T_838e8_row3_col6, #T_838e8_row4_col0, #T_838e8_row4_col1, #T_838e8_row4_col2, #T_838e8_row4_col3, #T_838e8_row4_col4, #T_838e8_row4_col5, #T_838e8_row4_col6, #T_838e8_row5_col0, #T_838e8_row5_col1, #T_838e8_row5_col2, #T_838e8_row5_col3, #T_838e8_row5_col4, #T_838e8_row5_col5, #T_838e8_row5_col6, #T_838e8_row6_col0, #T_838e8_row6_col1, #T_838e8_row6_col2, #T_838e8_row6_col3, #T_838e8_row6_col4, #T_838e8_row6_col5, #T_838e8_row6_col6, #T_838e8_row7_col0, #T_838e8_row7_col1, #T_838e8_row7_col2, #T_838e8_row7_col3, #T_838e8_row7_col4, #T_838e8_row7_col5, #T_838e8_row7_col6, #T_838e8_row8_col0, #T_838e8_row8_col1, #T_838e8_row8_col2, #T_838e8_row8_col3, #T_838e8_row8_col4, #T_838e8_row8_col5, #T_838e8_row8_col6, #T_838e8_row9_col0, #T_838e8_row9_col1, #T_838e8_row9_col2, #T_838e8_row9_col3, #T_838e8_row9_col4, #T_838e8_row9_col5, #T_838e8_row9_col6, #T_838e8_row10_col0, #T_838e8_row10_col1, #T_838e8_row10_col2, #T_838e8_row10_col3, #T_838e8_row10_col4, #T_838e8_row10_col5, #T_838e8_row10_col6, #T_838e8_row11_col0, #T_838e8_row11_col1, #T_838e8_row11_col2, #T_838e8_row11_col3, #T_838e8_row11_col4, #T_838e8_row11_col5, #T_838e8_row12_col0, #T_838e8_row12_col1, #T_838e8_row12_col2, #T_838e8_row12_col3, #T_838e8_row12_col4, #T_838e8_row12_col5, #T_838e8_row12_col6, #T_838e8_row13_col0, #T_838e8_row13_col1, #T_838e8_row13_col2, #T_838e8_row13_col3, #T_838e8_row13_col4, #T_838e8_row13_col5, #T_838e8_row13_col6, #T_838e8_row14_col0, #T_838e8_row14_col1, #T_838e8_row14_col2, #T_838e8_row14_col3, #T_838e8_row14_col4, #T_838e8_row14_col5, #T_838e8_row14_col6, #T_838e8_row15_col0, #T_838e8_row15_col1, #T_838e8_row15_col2, #T_838e8_row15_col3, #T_838e8_row15_col4, #T_838e8_row15_col5, #T_838e8_row15_col6, #T_838e8_row16_col0, #T_838e8_row16_col1, #T_838e8_row16_col2, #T_838e8_row16_col3, #T_838e8_row16_col4, #T_838e8_row16_col5, #T_838e8_row16_col6, #T_838e8_row17_col0, #T_838e8_row17_col1, #T_838e8_row17_col2, #T_838e8_row17_col3, #T_838e8_row17_col4, #T_838e8_row17_col5, #T_838e8_row17_col6, #T_838e8_row18_col0, #T_838e8_row18_col1, #T_838e8_row18_col2, #T_838e8_row18_col3, #T_838e8_row18_col4, #T_838e8_row18_col5, #T_838e8_row18_col6, #T_838e8_row19_col0, #T_838e8_row19_col1, #T_838e8_row19_col2, #T_838e8_row19_col3, #T_838e8_row19_col4, #T_838e8_row19_col5, #T_838e8_row19_col6 {
#   text-align: left;
# }
# #T_838e8_row0_col2, #T_838e8_row0_col3, #T_838e8_row0_col4, #T_838e8_row0_col5, #T_838e8_row3_col1, #T_838e8_row11_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_838e8_row0_col7, #T_838e8_row1_col7, #T_838e8_row2_col7, #T_838e8_row3_col7, #T_838e8_row4_col7, #T_838e8_row5_col7, #T_838e8_row6_col7, #T_838e8_row7_col7, #T_838e8_row8_col7, #T_838e8_row9_col7, #T_838e8_row10_col7, #T_838e8_row11_col7, #T_838e8_row12_col7, #T_838e8_row13_col7, #T_838e8_row14_col7, #T_838e8_row15_col7, #T_838e8_row17_col7, #T_838e8_row18_col7, #T_838e8_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_838e8_row16_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_838e8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >MAE</th>
#       <th class="col_heading level0 col2" >MSE</th>
#       <th class="col_heading level0 col3" >RMSE</th>
#       <th class="col_heading level0 col4" >R2</th>
#       <th class="col_heading level0 col5" >RMSLE</th>
#       <th class="col_heading level0 col6" >MAPE</th>
#       <th class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_838e8_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_838e8_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_838e8_row0_col1" class="data row0 col1" >4.2552</td>
#       <td id="T_838e8_row0_col2" class="data row0 col2" >181.8969</td>
#       <td id="T_838e8_row0_col3" class="data row0 col3" >13.2884</td>
#       <td id="T_838e8_row0_col4" class="data row0 col4" >0.6166</td>
#       <td id="T_838e8_row0_col5" class="data row0 col5" >0.6480</td>
#       <td id="T_838e8_row0_col6" class="data row0 col6" >1.3058</td>
#       <td id="T_838e8_row0_col7" class="data row0 col7" >2.0240</td>
#     </tr>
#     <tr>
#       <th id="T_838e8_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_838e8_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_838e8_row1_col1" class="data row1 col1" >5.0489</td>
#       <td id="T_838e8_row1_col2" class="data row1 col2" >184.7861</td>
#       <td id="T_838e8_row1_col3" class="data row1 col3" >13.3871</td>
#       <td id="T_838e8_row1_col4" class="data row1 col4" >0.6106</td>
#       <td id="T_838e8_row1_col5" class="data row1 col5" >0.7184</td>
#       <td id="T_838e8_row1_col6" class="data row1 col6" >1.5429</td>
#       <td id="T_838e8_row1_col7" class="data row1 col7" >1.1930</td>
#     </tr>
#     <tr>
#       <th id="T_838e8_level0_row2" class="row_heading level0 row2" >catboost</th>
#       <td id="T_838e8_row2_col0" class="data row2 col0" >CatBoost Regressor</td>
#       <td id="T_838e8_row2_col1" class="data row2 col1" >5.3530</td>
#       <td id="T_838e8_row2_col2" class="data row2 col2" >188.3483</td>
#       <td id="T_838e8_row2_col3" class="data row2 col3" >13.5370</td>
#       <td id="T_838e8_row2_col4" class="data row2 col4" >0.6028</td>
#       <td id="T_838e8_row2_col5" class="data row2 col5" >0.7506</td>
#       <td id="T_838e8_row2_col6" class="data row2 col6" >1.6625</td>
#       <td id="T_838e8_row2_col7" class="data row2 col7" >0.7070</td>
#     </tr>
#     <tr>
#       <th id="T_838e8_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_838e8_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_838e8_row3_col1" class="data row3 col1" >4.1644</td>
#       <td id="T_838e8_row3_col2" class="data row3 col2" >200.7543</td>
#       <td id="T_838e8_row3_col3" class="data row3 col3" >13.9771</td>
#       <td id="T_838e8_row3_col4" class="data row3 col4" >0.5751</td>
#       <td id="T_838e8_row3_col5" class="data row3 col5" >0.6612</td>
#       <td id="T_838e8_row3_col6" class="data row3 col6" >1.2748</td>
#       <td id="T_838e8_row3_col7" class="data row3 col7" >3.0130</td>
#     </tr>
#     <tr>
#       <th id="T_838e8_level0_row4" class="row_heading level0 row4" >knn</th>
#       <td id="T_838e8_row4_col0" class="data row4 col0" >K Neighbors Regressor</td>
#       <td id="T_838e8_row4_col1" class="data row4 col1" >4.9604</td>
#       <td id="T_838e8_row4_col2" class="data row4 col2" >207.2842</td>
#       <td id="T_838e8_row4_col3" class="data row4 col3" >14.2135</td>
#       <td id="T_838e8_row4_col4" class="data row4 col4" >0.5624</td>
#       <td id="T_838e8_row4_col5" class="data row4 col5" >0.6943</td>
#       <td id="T_838e8_row4_col6" class="data row4 col6" >1.5141</td>
#       <td id="T_838e8_row4_col7" class="data row4 col7" >0.2430</td>
#     </tr>
#     <tr>
#       <th id="T_838e8_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_838e8_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_838e8_row5_col1" class="data row5 col1" >5.9058</td>
#       <td id="T_838e8_row5_col2" class="data row5 col2" >207.0971</td>
#       <td id="T_838e8_row5_col3" class="data row5 col3" >14.2682</td>
#       <td id="T_838e8_row5_col4" class="data row5 col4" >0.5612</td>
#       <td id="T_838e8_row5_col5" class="data row5 col5" >0.8012</td>
#       <td id="T_838e8_row
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=-1, oob_score=False,
#                       random_state=577, verbose=0, warm_start=False)

# %%
modelo_proceso=create_model('rf')
# Out:
# <style type="text/css">
# #T_93f40_row10_col0, #T_93f40_row10_col1, #T_93f40_row10_col2, #T_93f40_row10_col3, #T_93f40_row10_col4, #T_93f40_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_93f40_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >MAE</th>
#       <th class="col_heading level0 col1" >MSE</th>
#       <th class="col_heading level0 col2" >RMSE</th>
#       <th class="col_heading level0 col3" >R2</th>
#       <th class="col_heading level0 col4" >RMSLE</th>
#       <th class="col_heading level0 col5" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93f40_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_93f40_row0_col0" class="data row0 col0" >4.1874</td>
#       <td id="T_93f40_row0_col1" class="data row0 col1" >158.9413</td>
#       <td id="T_93f40_row0_col2" class="data row0 col2" >12.6072</td>
#       <td id="T_93f40_row0_col3" class="data row0 col3" >0.6930</td>
#       <td id="T_93f40_row0_col4" class="data row0 col4" >0.6132</td>
#       <td id="T_93f40_row0_col5" class="data row0 col5" >1.1926</td>
#     </tr>
#     <tr>
#       <th id="T_93f40_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_93f40_row1_col0" class="data row1 col0" >3.8538</td>
#       <td id="T_93f40_row1_col1" class="data row1 col1" >107.2229</td>
#       <td id="T_93f40_row1_col2" class="data row1 col2" >10.3548</td>
#       <td id="T_93f40_row1_col3" class="data row1 col3" >0.7464</td>
#       <td id="T_93f40_row1_col4" class="data row1 col4" >0.6296</td>
#       <td id="T_93f40_row1_col5" class="data row1 col5" >1.4351</td>
#     </tr>
#     <tr>
#       <th id="T_93f40_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_93f40_row2_col0" class="data row2 col0" >3.9460</td>
#       <td id="T_93f40_row2_col1" class="data row2 col1" >212.5126</td>
#       <td id="T_93f40_row2_col2" class="data row2 col2" >14.5778</td>
#       <td id="T_93f40_row2_col3" class="data row2 col3" >0.5779</td>
#       <td id="T_93f40_row2_col4" class="data row2 col4" >0.6391</td>
#       <td id="T_93f40_row2_col5" class="data row2 col5" >1.1178</td>
#     </tr>
#     <tr>
#       <th id="T_93f40_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_93f40_row3_col0" class="data row3 col0" >4.6905</td>
#       <td id="T_93f40_row3_col1" class="data row3 col1" >234.7065</td>
#       <td id="T_93f40_row3_col2" class="data row3 col2" >15.3201</td>
#       <td id="T_93f40_row3_col3" class="data row3 col3" >0.4328</td>
#       <td id="T_93f40_row3_col4" class="data row3 col4" >0.6921</td>
#       <td id="T_93f40_row3_col5" class="data row3 col5" >1.7058</td>
#     </tr>
#     <tr>
#       <th id="T_93f40_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_93f40_row4_col0" class="data row4 col0" >5.4438</td>
#       <td id="T_93f40_row4_col1" class="data row4 col1" >325.6640</td>
#       <td id="T_93f40_row4_col2" class="data row4 col2" >18.0462</td>
#       <td id="T_93f40_row4_col3" class="data row4 col3" >0.5015</td>
#       <td id="T_93f40_row4_col4" class="data row4 col4" >0.7253</td>
#       <td id="T_93f40_row4_col5" class="data row4 col5" >1.5990</td>
#     </tr>
#     <tr>
#       <th id="T_93f40_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_93f40_row5_col0" class="data row5 col0" >4.3039</td>
#       <td id="T_93f40_row5_col1" class="data row5 col1" >163.6751</td>
#       <td id="T_93f40_row5_col2" class="data row5 col2" >12.7936</td>
#       <td id="T_93f40_row5_col3" class="data row5 col3" >0.6327</td>
#       <td id="T_93f40_row5_col4" class="data row5 col4" >0.6694</td>
#       <td id="T_93f40_row5_col5" class="data row5 col5" >1.6690</td>
#     </tr>
#     <tr>
#       <th id="T_93f40_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_93f40_row6_col0" class="data row6 col0" >4.4629</td>
#       <td id="T_93f40_row6_col1" class="data row6 col1" >192.7300</td>
#       <td id="T_93f40_row6_col2" class="data row6 col2" >13.8827</td>
#       <td id="T_93f40_row6_col3" class="data row6 col3" >0.5985</td>
#       <td id="T_93f40_row6_col4" class="data row6 col4" >0.6795</td>
#       <td id="T_93f40_row6_col5" class="data row6 col5" >1.3060</td>
#     </tr>
#     <tr>
#       <th id="T_93f40_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_93f40_row7_col0" class="data row7 col0" >3.8239</td>
#       <td id="T_93f40_row7_col1" class="data row7 col1" >118.5240</td>
#       <td id="T_93f40_row7_col2" class="data row7 col2" >10.8869</td>
#       <td id="T_93f40_row7_col3" class="data row7 col3" >0.7513</td>
#       <td id="T_93f40_row7_col4" class="data row7 col4" >0.6392</td>
#       <td id="T_93f40_row7_col5" class="data row7 col5" >1.1455</td>
#     </tr>
#     <tr>
#       <th id="T_93f40_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_93f40_row8_col0" class="data row8 col0" >3.5742</td>
#       <td id="T_93f40_row8_col1" class="data row8 col1" >106.9570</td>
#       <td id="T_93f40_row8_col2" class="data row8 col2" >10.3420</td>
#       <td id="T_93f40_row8_col3" class="data row8 col3" >0.6842</td>
#       <td id="T_93f40_row8_col4" class="data row8 col4" >0.5811</td>
#       <td id="T_93f40_row8_col5" class="data row8 col5" >0.9595</td>
#     </tr>
#     <tr>
#       <th id="T_93f40_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_93f40_row9_col0" class="data row9 col0" >4.2656</td>
#       <td id="T_93f40_row9_col1" class="data row9 col1" >198.0358</td>
#       <td id="T_93f40_row9_col2" class="data row9 col2" >14.0725</td>
#       <td id="T_93f40_row9_col3" class="data row9 col3" >0.5474</td>
#       <td id="T_93f40_row9_col4" class="data row9 col4" >0.6121</td>
#       <td id="T_93f40_row9_col5" class="data row9 col5" >0.9281</td>
#     </tr>
#     <tr>
#       <th id="T_93f40_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_93f40_row10_col0" class="data row10 col0" >4.2552</td>
#       <td id="T_93f40_row10_col1" class="data row10 col1" >181.8969</td>
#       <td id="T_93f40_row10_col2" class="data row10 col2" >13.2884</td>
#       <td id="T_93f40_row10_col3" class="data row10 col3" >0.6166</td>
#       <td id="T_93f40_row10_col4" class="data row10 col4" >0.6480</td>
#       <td id="T_93f40_row10_col5" class="data row10 col5" >1.3058</td>
#     </tr>
#     <tr>
#       <th id="T_93f40_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_93f40_row11_col0" class="data row11 col0" >0.5059</td>
#       <td id="T_93f40_row11_col1" class="data row11 col1" >63.9064</td>
#       <td id="T_93f40_row11_col2" class="data row11 col2" >2.3056</td>
#       <td id="T_93f40_row11_col3" class="data row11 col3" >0.0996</td>
#       <td id="T_93f40_row11_col4" class="data row11 col4" >0.0410</td>
#       <td id="T_93f40_row11_col5" class="data row11 col5" >0.2704</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_model(modelo_proceso,'error')

# %%
interpret_model(modelo_proceso)

# %%
plot_model(modelo_proceso,'learning')

# %%
plot_model(modelo_proceso,'rfe')
# Out:
# IntProgress(value=0, description='Processing: ', max=5)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6712/492702560.py in <module>
# ----> 1 plot_model(modelo_proceso,'rfe')
#
# ~\anaconda3\envs\env1\lib\site-packages\pycaret\regression.py in plot_model(estimator, plot, scale, save, fold, fit_kwargs, groups, use_train_data, verbose, display_format)
#    1500     """
#    1501
# -> 1502     return pycaret.internal.tabular.plot_model(
#    1503         estimator=estimator,
#    1504         plot=plot,
#
# ~\anaconda3\envs\env1\lib\site-packages\pycaret\internal\tabular.py in plot_model(estimator, plot, scale, save, fold, fit_kwargs, groups, feature_name, label, use_train_data, verbose, system, display, display_format, is_in_evaluate)
#    7386
#    7387         # execute the plot method
# -> 7388         ret = locals()[plot]()
#    7389         if ret:
#    7390             plot_filename = ret
#
# ~\anaconda3\envs\env1\lib\site-packages\pycaret\internal\tabular.py in rfe()
#    6780
#    6781             visualizer = RFECV(pipeline_with_model, cv=cv)
# -> 6782             show_yellowbrick_plot(
#    6783                 visualizer=visualizer,
#    6784                 X_train=data_X,
#
# ~\anaconda3\envs\env1\lib\site-packages\pycaret\internal\plots\yellowbrick.py in show_yellowbrick_plot(visualizer, X_train, y_train, X_test, y_test, name, handle_train, handle_test, scale, save, fit_kwargs, groups, display, display_format, **kwargs)
#      87     elif handle_train == "fit":
#      88         logger.info("Fitting Model")
# ---> 89         visualizer.fit(X_train, y_train, **fit_kwargs_and_kwargs)
#      90     elif handle_train == "fit_transform":
#      91         logger.info("Fitting & Transforming Model")
#
# ~\anaconda3\envs\env1\lib\site-packages\yellowbrick\model_selection\rfecv.py in fit(self, X, y)
#     195         for n_features_to_select in self.n_feature_subsets_:
#     196             rfe.set_params(n_features_to_select=n_features_to_select)
# --> 197             scores.append(cross_val_score(rfe, X, y, **cv_params))
#     198
#     199         # Convert scores to array
#
# ~\anaconda3\envs\env1\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\envs\env1\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     399     scorer = check_scoring(estimator, scoring=scoring)
#     400
# --> 401     cv_results = cross_validate(estimator=estimator, X=X, y=y, groups=groups,
#     402                                 scoring={'score': scorer}, cv=cv,
#     403                                 n_jobs=n_jobs, verbose=verbose,
#
# ~\anaconda3\envs\env1\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\envs\env1\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     240     parallel = Parallel(n_jobs=n_jobs, verbose=verbose,
#     241                         pre_dispatch=pre_dispatch)
# --> 242     scores = parallel(
#     243         delayed(_fit_and_score)(
#     244             clone(estimator), X, y, scorers, train, test, verbose, None,
#
# ~\anaconda3\envs\env1\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1042                 self._iterating = self._original_iterator is not None
#    1043
# -> 1044             while self.dispatch_one_batch(iterator):
#    1045                 pass
#    1046
#
# ~\anaconda3\envs\env1\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     857                 return False
#     858             else:
# --> 859                 self._dispatch(tasks)
#     860                 return True
#     861
#
# ~\anaconda3\envs\env1\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     775         with self._lock:
#     776             job_idx = len(self._jobs)
# --> 777             job = self._backend.apply_async(batch, callback=cb)
#     778             # A job can complete so quickly than its callback is
#     779             # called before we get here, causing self._jobs to
#
# ~\anaconda3\envs\env1\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\envs\env1\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\anaconda3\envs\env1\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\envs\env1\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\envs\env1\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     529             estimator.fit(X_train, **fit_params)
#     530         else:
# --> 531             estimator.fit(X_train, y_train, **fit_params)
#     532
#     533     except Exception as e:
#
# ~\anaconda3\envs\env1\lib\site-packages\sklearn\feature_selection\_rfe.py in fit(self, X, y)
#     149             The target values.
#     150         """
# --> 151         return self._fit(X, y)
#     152
#     153     def _fit(self, X, y, step_score=None):
#
# ~\anaconda3\envs\env1\lib\site-packages\sklearn\feature_selection\_rfe.py in _fit(self, X, y, step_score)
#     194                 print("Fitting estimator with %d features." % np.sum(support_))
#     195
# --> 196             estimator.fit(X[:, features], y)
#     197
#     198             # Get coefs
#
# ~\anaconda3\envs\env1\lib\site-packages\pycaret\internal\pipeline.py in fit(self, X, y, **fit_kwargs)
#     116
#     117     def fit(self, X, y=None, **fit_kwargs):
# --> 118         result = super().fit(X, y=y, **fit_kwargs)
#     119
#     120         self._carry_over_final_estimator_fit_vars()
#
# ~\anaconda3\envs\env1\lib\site-packages\imblearn\pipeline.py in fit(self, X, y, **fit_params)
#     279                                  self._log_message(len(self.steps) - 1)):
#     280             if self._final_estimator != "passthrough":
# --> 281                 self._final_estimator.fit(Xt, yt, **fit_params)
#     282         return self
#     283
#
# ~\anaconda3\envs\env1\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     384             # parallel_backend contexts set at a higher level,
#     385             # since correctness does not rely on using threads.
# --> 386             trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#     387                              **_joblib_parallel_args(prefer='threads'))(
#     388                 delayed(_parallel_build_trees)(
#
# ~\anaconda3\envs\env1\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1062                 self._backend.stop_call()
#    1063             if not self._managed_backend:
# -> 1064                 self._terminate_backend()
#    1065             self._jobs = list()
#    1066             self._pickle_cache = None
#
# ~\anaconda3\envs\env1\lib\site-packages\joblib\parallel.py in _terminate_backend(self)
#     755     def _terminate_backend(self):
#     756         if self._backend is not None:
# --> 757             self._backend.terminate()
#     758
#     759     def _dispatch(self, batch):
#
# ~\anaconda3\envs\env1\lib\site-packages\joblib\_parallel_backends.py in terminate(self)
#     549             # calls, but cleanup the temporary resources that the Parallel call
#     550             # created. This 'hack' requires a private, low-level operation.
# --> 551             self._workers._temp_folder_manager._unlink_temporary_resources(
#     552                 context_id=self.parallel._id
#     553             )
#
# ~\anaconda3\envs\env1\lib\site-packages\joblib\_memmapping_reducer.py in _unlink_temporary_resources(self, context_id)
#     625                         os.path.join(temp_folder, filename), "file"
#     626                     )
# --> 627                 self._try_delete_folder(
#     628                     allow_non_empty=False, context_id=context_id
#     629                 )
#
# ~\anaconda3\envs\env1\lib\site-packages\joblib\_memmapping_reducer.py in _try_delete_folder(self, allow_non_empty, context_id)
#     652             temp_folder = self._cached_temp_folders[context_id]
#     653             try:
# --> 654                 delete_folder(
#     655                     temp_folder, allow_non_empty=allow_non_empty
#     656                 )
#
# ~\anaconda3\envs\env1\lib\site-packages\joblib\disk.py in delete_folder(folder_path, onerror, allow_non_empty)
#     134                         # yet.
#     135                         raise
# --> 136                 time.sleep(RM_SUBDIRS_RETRY_TIME)
#
# KeyboardInterrupt:

# %%
plot_model(modelo_proceso,'feature')

# %%
#save_model(modelo_proceso,model_name='modelo_procesos')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=[],
#                                        target='dias proceso',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_stra...
#                   RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                         criterion='mse', max_depth=None,
#                                         max_features='auto', max_leaf_nodes=None,
#                                         max_samples=None,
#                                         min_impurity_decrease=0.0,
#                                         min_impurity_split=None,
#                                         min_samples_leaf=1, min_samples_split=2,
#                                         min_weight_fraction_leaf=0.0,
#                                         n_estimators=100, n_jobs=-1,
#                                         oob_score=False, random_state=1370,
#                                         verbose=0, warm_start=False)]],
#           verbose=False),
#  'modelo_procesos.pkl')

# %%
df.columns
# Out:
# Index(['NÚMERO PEDIDO', 'ORDEN NÚMERO', 'FECHA ORDEN', 'FECHA APROBACION',
#        'CATEGORÍA', 'SUBCATEGORIA', 'PROVEEDOR', 'USUARIO',
#        'USUARIO APROBADOR', 'DIRECCION PEDIDO', 'PORTAL', 'ESTADO',
#        'PRODUCTO O SERVICIO', 'CANTIDAD PEDIDA', 'PRECIO UNITARIO',
#        'PRECIO UNITARIO + IVA', 'IVA', 'TOTAL SIN IVA', 'TOTAL + IVA',
#        'FECHA ULTIMO MOVIMIENTO', 'dia fecha aprobacion',
#        'mes fecha aprobacion', 'semana del año aprobacion', 'dia fecha orden',
#        'mes fecha orden', 'semana del año orden', 'dias para aprobación',
#        'dias proceso'],
#       dtype='object')

# %%
batche_prueba=df[['NÚMERO PEDIDO', 'ORDEN NÚMERO', 'FECHA ORDEN','CATEGORÍA','PRODUCTO O SERVICIO','CANTIDAD PEDIDA',
                 'USUARIO',
       'USUARIO APROBADOR','PROVEEDOR']]
batche_prueba.to_excel('batche_prueba.xlsx')
